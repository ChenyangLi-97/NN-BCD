# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Tensor_Layer_for_Deep_Neural_Network_Compression-master/Tensor_Layer_for_Deep_Neural_Network_Compression-master
# Out:
# /content/drive/My Drive/Colab Notebooks/Tensor_Layer_for_Deep_Neural_Network_Compression-master/Tensor_Layer_for_Deep_Neural_Network_Compression-master

# %%
#!pip install tensorly
#!pip install torch_dct

# %%
from common import *
from decomposition import *
from nets import *
from transform_based_network import *

# %% [markdown]
# Uncompressed model # of parameters: 6,596,522

# %% [markdown]
# number of parameter: 1,285,386

# %% [markdown]
# CR = 0.1949

# %%
model0 = Own()

# %%
run_all('mnist', model0, decomp='tucker', i=20, rate=0.01)
# Out:
# ==> Loading data..
# ==> Building model..
# /usr/local/lib/python3.10/dist-packages/tensorly/tucker_tensor.py:425: RuntimeWarning: Given only one int for 'rank' for decomposition a tensor of order 2. Using this rank for all modes.
#   warnings.warn(message, RuntimeWarning)
# Streaming output truncated to the last 5000 lines.
# torch.Size([100, 10]) torch.Size([100])
# torch.Size([100, 10]) torch.Size([100])
# torch.Size([100, 10]) torch.Size([100])
# torch.Size([100, 10]) torch.Size([100])
# torch.Size([100, 10]) torch.Size([100])
# torch.Size([100, 10]) torch.Size([100])
# torch.Size([100, 10]) torch.Size([100])
# =torch.Size([100, 10]) torch.Size([100])
# torch.Size([100, 10]) torch.Size([100])
# torch.Size([100, 10]) torch.Size([100])
# torch.Size([100, 10]) torch.Size([100])
# torch.Size([100, 10]) torch.Size([100])
# torch.Size([100, 10]) torch.Size([100])
# torch.Size([100, 10]) torch.Size([100])
# torch.Size([100, 10]) torch.Size([100])
# ...
